# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.4 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/drive/MyDrive/dataset_pbls5_yolo.zip
# Out:
# Archive:  /content/drive/MyDrive/dataset_pbls5_yolo.zip
#    creating: dataset_pbls5_yolo/
#   inflating: dataset_pbls5_yolo/data.yaml
#    creating: dataset_pbls5_yolo/test/
#    creating: dataset_pbls5_yolo/test/images/
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (2).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (20).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (45).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (54).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (55).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (59).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (63).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (66).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (71).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu hijau (88).jpg
#   inflating: dataset_pbls5_yolo/test/images/lampu kuning (19).jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.info()

results = model.train(data="/content/dataset_pbls5_yolo/data.yaml", epochs=100, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
