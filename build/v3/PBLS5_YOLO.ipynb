# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.5 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/drive/MyDrive/ts_new_yolo.zip
# Out:
# Archive:  /content/drive/MyDrive/ts_new_yolo.zip
#    creating: dataset/
#   inflating: dataset/data.yaml
#    creating: dataset/test/
#    creating: dataset/test/images/
#   inflating: dataset/test/images/lampu merah (10).jpg
#   inflating: dataset/test/images/lampu merah (13).jpg
#   inflating: dataset/test/images/lampu merah (2).jpg
#   inflating: dataset/test/images/lampu merah (31).jpg
#   inflating: dataset/test/images/lampu merah (38).jpg
#   inflating: dataset/test/images/lampu merah (5).jpg
#   inflating: dataset/test/images/lampu merah (52).jpg
#   inflating: dataset/test/images/lampu merah (64).jpg
#   inflating: dataset/test/images/lampu merah (7).jpg
#   inflating: dataset/test/images/lampu merah (79).jpg
#   inflating: dataset/test/images/larangan belok kiri (1).jpg
#   inflating: dataset/test/images/larangan belok kiri (12).jpg
#   inflating: dataset/test/images/larangan belok kiri (24).jpg
#   inflating: dataset/test/images/larangan belok kiri (27).jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.info()

results = model.train(data="/content/dataset/data.yaml", epochs=100, imgsz=640)
# Out:
# YOLOv8n summary: 129 layers, 3,157,200 parameters, 0 gradients, 8.9 GFLOPs
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
